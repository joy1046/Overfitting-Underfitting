# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.model_selection import train_test_split, learning_curve
from sklearn.metrics import mean_squared_error, accuracy_score
# %matplotlib inline

# %%
MSE_test = []
MSE_train = []

# %% [markdown]
# ## Degree One

# %%
#generating x and y
X = np.random.rand(200, 1) * 500
X = X.reshape(-1, 1)
y = (X ** 4) + 2 * (X ** 3) - (X ** 2) - X + 1
y = np.random.normal(size=y.shape) + y

# %%
#splitting X and y into training and testing sets

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
clf_one = LinearRegression(normalize=True)

# %%
clf_one.fit(X_train, y_train)
# Out:
# LinearRegression(normalize=True)

# %%
# Calculating MSE

MSE_test.append(mean_squared_error(y_test, clf_one.predict(X_test)))
MSE_train.append(mean_squared_error(y_train, clf_one.predict(X_train)))

# %%
print('test score:', clf_one.score(X_test, y_test))
print('train score:', clf_one.score(X_train, y_train))
# Out:
# test score: 0.6186521992731404
# train score: 0.7550690389564841

# %%
X_line = np.arange(0, 510, 0.1).reshape(-1,1)
plt.plot(X_line, clf_one.predict(X_line), 'r--')
plt.plot(X_train, y_train, 'bo', label='Train data')
plt.plot(X_test, y_test, 'co', label='Test data')
plt.legend()
plt.title('Degree one')
plt.grid()
plt.show()

# %%
train_sizes, train_score, test_score = learning_curve(clf_one, X_train, y_train)
plt.plot(train_sizes, train_score.mean(axis=1), 'go-', label='train')
plt.plot(train_sizes, test_score.mean(axis=1), 'bo-', label='test')
plt.legend()
plt.grid()

# %% [markdown]
# ## Degree Two

# %%
# adding polynomial feature
poly = PolynomialFeatures(degree=2)
X_train_poly, X_test_poly = poly.fit_transform(X_train), poly.fit_transform(X_test)

# %%
# building the model

clf_two = LinearRegression(normalize=True)
clf_two.fit(X_train_poly, y_train)
# Out:
# LinearRegression(normalize=True)

# %%
MSE_test.append(mean_squared_error(y_test, clf_two.predict(X_test_poly)))
MSE_train.append(mean_squared_error(y_train, clf_two.predict(X_train_poly)))

# %%
print('test score:', clf_two.score(X_test_poly, y_test))
print('train score:', clf_two.score(X_train_poly, y_train))
# Out:
# test score: 0.9712557614528339
# train score: 0.9821563055084512

# %%
# visualization

X_line = np.arange(-20, 510, 0.01).reshape(-1, 1)
plt.plot(X_line, clf_two.predict(poly.fit_transform(X_line)), 'r--')
plt.plot(X_train, y_train, 'bo', label='Train data')
plt.plot(X_test, y_test, 'co', label='Test data')
plt.legend()
plt.title('Degree two')
plt.grid()
plt.show()

# %%
train_sizes, train_score, test_score = learning_curve(clf_two, X_train_poly, y_train)
plt.plot(train_sizes, train_score.mean(axis=1), 'go-', label='train')
plt.plot(train_sizes, test_score.mean(axis=1), 'bo-', label='test')
plt.legend()
plt.grid()

# %% [markdown]
# ## Degree Four

# %%
poly = PolynomialFeatures(degree=4)
X_train_poly, X_test_poly = poly.fit_transform(X_train), poly.fit_transform(X_test)

# %%
clf_three = LinearRegression(normalize=True)
clf_three.fit(X_train_poly, y_train)
# Out:
# LinearRegression(normalize=True)

# %%
MSE_test.append(mean_squared_error(y_test, clf_three.predict(X_test_poly)))
MSE_train.append(mean_squared_error(y_train, clf_three.predict(X_train_poly)))

# %%
print('test score:', clf_three.score(X_test_poly, y_test))
print('train score:', clf_three.score(X_train_poly, y_train))
# Out:
# test score: 1.0
# train score: 1.0

# %%
X_line = np.arange(-20, 510, 0.01).reshape(-1, 1)
plt.plot(X_line, clf_three.predict(poly.fit_transform(X_line)), 'r--')
plt.plot(X_train, y_train, 'bo', label='Train data')
plt.plot(X_test, y_test, 'co', label='Test data')
plt.legend()
plt.title('Degree Four')
plt.grid()
plt.show()

# %%
train_sizes, train_score, test_score = learning_curve(clf_three, X_train_poly, y_train)
plt.plot(train_sizes, train_score.mean(axis=1), 'go-', label='train')
plt.plot(train_sizes, test_score.mean(axis=1), 'bo-', label='test')
plt.grid()
plt.legend()

# %% [markdown]
# ## Degree Eight

# %%
poly = PolynomialFeatures(degree=8)
X_train_poly, X_test_poly = poly.fit_transform(X_train), poly.fit_transform(X_test)

# %%
clf_four = LinearRegression(normalize=True)
clf_four.fit(X_train_poly, y_train)
# Out:
# LinearRegression(normalize=True)

# %%
MSE_test.append(mean_squared_error(y_test, clf_four.predict(X_test_poly)))
MSE_train.append(mean_squared_error(y_train, clf_four.predict(X_train_poly)))

# %%
print('test score:', clf_four.score(X_test_poly, y_test))
print('train score:', clf_four.score(X_train_poly, y_train))
# Out:
# test score: 1.0
# train score: 1.0

# %%
X_line = np.arange(-20, 510, 0.01).reshape(-1, 1)
plt.plot(X_line, clf_four.predict(poly.fit_transform(X_line)), 'r--')
plt.plot(X_train, y_train, 'bo', label='Train data')
plt.plot(X_test, y_test, 'co', label='Test data')
plt.legend()
plt.title('Degree Eight')
plt.grid()
plt.show()

# %%
train_sizes, train_score, test_score = learning_curve(clf_four, X_train_poly, y_train)
plt.plot(train_sizes, train_score.mean(axis=1), 'go-', label='train')
plt.plot(train_sizes, test_score.mean(axis=1), 'bo-', label='test')
plt.grid()
plt.legend()

# %% [markdown]
# ## Degree Sixteen

# %%
poly = PolynomialFeatures(degree=16)
X_train_poly, X_test_poly = poly.fit_transform(X_train), poly.fit_transform(X_test)

# %%
clf_five = LinearRegression(normalize=True)
clf_five.fit(X_train_poly, y_train)
# Out:
# LinearRegression(normalize=True)

# %%
MSE_test.append(mean_squared_error(y_test, clf_five.predict(X_test_poly)))
MSE_train.append(mean_squared_error(y_train, clf_five.predict(X_train_poly)))

# %%
print('test score:', clf_five.score(X_test_poly, y_test))
print('train score:', clf_five.score(X_train_poly, y_train))
# Out:
# test score: 1.0
# train score: 1.0

# %%
X_line = np.arange(-10, 510, 0.001).reshape(-1, 1)
plt.plot(X_line, clf_five.predict(poly.fit_transform(X_line)), 'r--')
plt.plot(X_train, y_train, 'bo', label='Train data')
plt.plot(X_test, y_test, 'co', label='Test data')
plt.legend()
plt.title('Degree Sixteen')
plt.grid()
plt.show()

# %%
train_sizes, train_score, test_score = learning_curve(clf_five, X_train_poly, y_train)
plt.plot(train_sizes, train_score.mean(axis=1), 'go-', label='train')
#plt.plot(train_sizes, test_score.mean(axis=1), 'bo-', label='test')
plt.grid()
plt.legend()

# %% [markdown]
# ## MSE

# %%
x = [1, 2, 4, 8, 16]
plt.plot(x, MSE_test, 'go-', label='test')
plt.plot(x, MSE_train, 'bo-', label='train')
plt.xlabel('Degree')
plt.ylabel('MSE')
plt.grid()
